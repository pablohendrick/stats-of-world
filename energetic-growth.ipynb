# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv ('/kaggle/input/global-energy-substitution-from-1983-to-2022/global-energy-substitution.csv')

# %%
data.head(10)
# Out:
#    Year  Other_renewables    Biofuels     Solar       Wind  Hydropower  \
# 0  1983         211.77058   49.019240  0.008871   0.096974   5552.5425
# 1  1984         236.32065   57.806423  0.018662   0.132342   5740.6200
# 2  1985         243.15495   68.410090  0.034737   0.189898   5852.6050
# 3  1986         263.68542   84.202990  0.044898   0.410523   5931.9126
# 4  1987         282.44330   85.330120  0.031353   0.577727   6012.1157
# 5  1988         290.86093   89.560196  0.030149   0.980478   6204.8037
# 6  1989         322.35043   95.689240  0.775391   7.835361   6172.9750
# 7  1990         361.19138  106.642880  1.148346  10.741176   6383.7080
# 8  1991         376.81265  110.728714  1.494234  12.082573   6531.1080
# 9  1992         404.78116  108.796330  1.379965  13.994874   6530.3900
#
#      Nuclear        Gas        Oil       Coal  Traditional_biomass
# 0  2933.4590  14703.833  32956.613  22046.346                10321
# ...

# %%
df.agg(['mean', 'median'])
# Out:
#           Biofuels       Solar         Wind  Hydropower      Nuclear  \
# mean    424.965961  406.457205  1009.701726  8334.41752  6466.833565
# median  168.664415    5.897006   168.213760  7758.22050  6755.572500
#
#                  Gas           Oil        Coal  Traditional_biomass
# mean    26663.223025  43939.467375  33599.5663            11487.125
# median  25379.894500  44164.131500  30234.5555            11408.500

# %%
df.skew()
# Out:
# Biofuels               0.740226
# Solar                  2.385955
# Wind                   1.607910
# Hydropower             0.260438
# Nuclear               -1.566970
# Gas                    0.272539
# Oil                   -0.149591
# Coal                   0.178951
# Traditional_biomass    0.057463
# dtype: float64

# %%
df.kurtosis()
# Out:
# Biofuels              -1.128663
# Solar                  5.217166
# Wind                   1.621021
# Hydropower            -1.250416
# Nuclear                2.239355
# Gas                   -1.161366
# Oil                   -1.223790
# Coal                  -1.816633
# Traditional_biomass   -0.828677
# dtype: float64

# %%
df.skew()
# Out:
# Biofuels               0.740226
# Solar                  2.385955
# Wind                   1.607910
# Hydropower             0.260438
# Nuclear               -1.566970
# Gas                    0.272539
# Oil                   -0.149591
# Coal                   0.178951
# Traditional_biomass    0.057463
# dtype: float64

# %%
df.kurtosis()
# Out:
# Biofuels              -1.128663
# Solar                  5.217166
# Wind                   1.621021
# Hydropower            -1.250416
# Nuclear                2.239355
# Gas                   -1.161366
# Oil                   -1.223790
# Coal                  -1.816633
# Traditional_biomass   -0.828677
# dtype: float64

# %%
df = data[['Biofuels', 'Solar', 'Wind', 'Hydropower', 'Nuclear', 'Gas', 'Oil', 
          'Coal', 'Traditional_biomass']]
corr_matrix = df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.2)
plt.title('Heatmap Correlation')
plt.show()

# %%
data['Oil'].plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
data['Coal'].plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
data['Gas'].plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
data['Nuclear'].plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
data ['Biofuels'].plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
data['Solar'].plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
data['Wind'].plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
data['Hydropower'].plot(figsize=(12,6))
# Out:
# <Axes: >
